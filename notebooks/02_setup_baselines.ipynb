# %% [markdown]
# ## Baselines
#
# Using baselines to get itinial metris to be compeared after mlp design and test

# %%
# Imports

import pandas as pd
import numpy as np
import os

# %%
# Reading processed
